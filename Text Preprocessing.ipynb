# %%
# ------ Load Dataset ---------
# import library
import pandas as pd
import numpy as np

# membaca file csv
TWEET_DATA = pd.read_csv("LGBT.csv")

# mengganti nama kolom
TWEET_DATA.columns = ['tweet']

# menampilkan data bagian head
TWEET_DATA.head()

#TWEET_DATA[['tweet']] jika ingin menampilkan tweet saja
# Out:
#                                                tweet
# 0  b'RT @Nadhezda8: Dukung Pidanakan LGBT #HukumP...
# 1  b'Rekomendasi kemeja retro, Sista. Yang jelas ...
# 2  b'RT @mihrabku: Inilah kacaunya portal online ...
# 3  b'Porn, LGBT dan cebol Jangan berani nongol Ka...
# 4  b'RT @NewOpang: Toko NU jualan lgbt https://t....

# %%
# ------ Case Folding ---------
# mengubah semua huruf menjadi kecil
TWEET_DATA['tweet'] = TWEET_DATA['tweet'].str.lower()

print('Hasil Case Folding :')
TWEET_DATA.head()
# Out:
# Hasil Case Folding :
#                                                tweet
# 0  b'rt @nadhezda8: dukung pidanakan lgbt #hukump...
# 1  b'rekomendasi kemeja retro, sista. yang jelas ...
# 2  b'rt @mihrabku: inilah kacaunya portal online ...
# 3  b'porn, lgbt dan cebol jangan berani nongol ka...
# 4  b'rt @newopang: toko nu jualan lgbt https://t....

# %%
# ------ Tokenizing ---------
# import library
import string 
import re # regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# menghapus karakter spesial
def remove_tweet_special(text):
    # menghapus tab, baris baru & back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, dll.)
    text = text.encode('ascii', 'replace').decode('ascii')
    text = re.sub("b'|b\"",'',text)
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_tweet_special)

# menghapus nomor
def remove_number(text):
    return  re.sub(r"\d+", "", text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_number)

# menghapus tanda baca
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_punctuation)

# menghapus spasi awal & akhir
def remove_whitespace_LT(text):
    return text.strip()

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_whitespace_LT)

# menghapus banyak spasi menjadi satu spasi
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_whitespace_multiple)

# menghapus karakter tunggal
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_singl_char)

# NLTK tokenisasi kata 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

TWEET_DATA['tweet_tokens'] = TWEET_DATA['tweet'].apply(word_tokenize_wrapper)

print('Hasil Tokenizing :') 
TWEET_DATA.head()
# Out:
# Hasil Tokenizing :
#                                                tweet  \
# 0  rt dukung pidanakan lgbt hidayat nurwahid lgbt...
# 1  rekomendasi kemeja retro sista yang jelas ngga...
# 2  rt inilah kacaunya portal online yang tak bela...
# 3  porn lgbt dan cebol jangan berani nongol kalo ...
# 4                             rt toko nu jualan lgbt
#
#                                         tweet_tokens
# 0  [rt, dukung, pidanakan, lgbt, hidayat, nurwahi...
# 1  [rekomendasi, kemeja, retro, sista, yang, jela...
# 2  [rt, inilah, kacaunya, portal, online, yang, t...
# 3  [porn, lgbt, dan, cebol, jangan, berani, nongo...
# 4                       [rt, toko, nu, jualan, lgbt]

# %%
# ------ Filtering (Stopword Removal) --------- 
from nltk.corpus import stopwords

# ---------------------------- stopword from NLTK stopword -------------------------------------
# stopword indonesia
list_stopwords = stopwords.words('indonesian')

# ---------------------------- menambahkan stopword manual  ------------------------------------
# menambahkan stopword tambahan
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 'si', 'tau', 'tdk', 'tuh', 'utk', 'ya','jd',
                       'jgn', 'sdh', 'aja', 'n', 't', 'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt', 'noh'
                       '&amp', 'yah', 'gk', 'ya', 'mo', 'mah', 'oh', 'bgt', 'ah', 'lg', 'gini', 'gni', 'dll'
                       'hny', 'in', 'gk', 'gin', 'mh', 'ma'])

# --------------------------- menambahkan stopword dari file txt -------------------------------
# membaca file stopword txt menggunakan pandas
txt_stopword = pd.read_csv("stopwordbahasa.txt", names= ["stopwords"], header = None)

# konversi string stopword ke daftar & tambahkan stopword tambahan
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# konversi list ke dictionary
list_stopwords = set(list_stopwords)


# hapus stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

TWEET_DATA['tweet_tokens_WSW'] = TWEET_DATA['tweet_tokens'].apply(stopwords_removal) 

print('Hasil Filtering :') 
TWEET_DATA.head()
# Out:
# Hasil Filtering :
#                                                tweet  \
# 0  rt dukung pidanakan lgbt hidayat nurwahid lgbt...
# 1  rekomendasi kemeja retro sista yang jelas ngga...
# 2  rt inilah kacaunya portal online yang tak bela...
# 3  porn lgbt dan cebol jangan berani nongol kalo ...
# 4                             rt toko nu jualan lgbt
#
#                                         tweet_tokens  \
# 0  [rt, dukung, pidanakan, lgbt, hidayat, nurwahi...
# 1  [rekomendasi, kemeja, retro, sista, yang, jela...
# 2  [rt, inilah, kacaunya, portal, online, yang, t...
# 3  [porn, lgbt, dan, cebol, jangan, berani, nongo...
# 4                       [rt, toko, nu, jualan, lgbt]
#
#                                     tweet_tokens_WSW
# 0  [dukung, pidanakan, lgbt, hidayat, nurwahid, l...
# 1  [rekomendasi, kemeja, retro, sista, nggak, kek...
# 2  [kacaunya, portal, online, belajar, menulis, b...
# 3  [porn, lgbt, cebol, berani, nongol, ditampol, ...
# 4                           [toko, nu, jualan, lgbt]

# %%
# ------ Stemming --------- 
# import package Sastrawi 
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# membuat stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in TWEET_DATA['tweet_tokens_WSW']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# menerapkan stemmed term ke dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

TWEET_DATA['tweet_tokens_stemmed'] = TWEET_DATA['tweet_tokens_WSW'].swifter.apply(get_stemmed_term)

print('Hasil Stemming :') 
TWEET_DATA.head()
# Out:
# 1339
# ------------------------
# dukung : dukung
# pidanakan : pidana
# lgbt : lgbt
# hidayat : hidayat
# nurwahid : nurwahid
# bertentangan : tentang
# pancasila : pancasila
# rekomendasi : rekomendasi
# kemeja : kemeja
# retro : retro
# sista : sista
# nggak : nggak
# kek : kek
# firaun : firaun
# tag : tag
# libur : libur
# siang : siang
# ozil : ozil
# kacaunya : kacau
# portal : portal
# online : online
# belajar : ajar
# menulis : tulis
# berita : berita
# cuitan : cuit
# nadir : nadir
# dibenturkan : bentur
# pernyataan : nyata
# hrs : hrs
# porn : porn
# cebol : cebol
# berani : berani
# nongol : nongol
# ditampol : ditampol
# khusus : khusus
# oposisi : oposisi
# salfol : salfol
# toko : toko
# nu : nu
# jualan : jual
# kaum : kaum
# predator : predator
# normal : normal
# mrk : mrk
# berburu : buru
# sebyk : sebyk
# mgkn : mgkn
# manusia : manusia
# bareng : bareng
# nyembah : nyembah
# iblis : iblis
# msk : msk
# neraka : neraka
# mengundang : undang
# bencana : bencana
# alam : alam
# peduli : peduli
# lingkungan : lingkung
# gue : gue
# maksanya : maksanya
# btw : btw
# hidup : hidup
# berdampingan : damping
# ente : ente
# sumut : sumut
# perangi : rang
# tu : tu
# disitu : situ
# cmn : cmn
# koar : koar
# kerja : kerja
# nyepil : nyepil
# gitu : gitu
# dibilang : bilang
# buzzerp : buzzerp
# mulut : mulut
# sampah : sampah
# bisanya : bisa
# mengkritik : kritik
# kinerja : kerja
# berseberangan : berangan
# nonton : nonton
# menyimpang : simpang
# alias : alias
# off : off
# ukhty : ukhty
# ri : ri
# dimatikan : mati
# cair : cair
# cuan : cuan
# komunitas : komunitas
# sekedar : dar
# nanya : nanya
# heran : heran
# indonesia : indonesia
# kebanyakan : banyak
# munafik : munafik
# memperjuangkan : juang
# hak : hak
# fyi : fyi
# tindak : tindak
# pidananya : pidana
# disaat : saat
# mengucilkan : kucil
# menjauhkan : jauh
# keluarganya : keluarga
# teriak : teriak
# bendera : bendera
# tauhid : tauhid
# antum : antum
# bakar : bakar
# kibarkan : kibar
# kebenaran : benar
# salahkan : salah
# kebatilan : batil
# bela : bela
# qatar : qatar
# haramkan : haram
# piala : piala
# dunia : dunia
# menukar : tukar
# agama : agama
# turnamen : turnamen
# qi : qi
# surga : surga
# buron : buron
# korupsi : korupsi
# singapore : singapore
# lgbthanya : lgbthanya
# negara : negara
# broker : broker
# miskin : miskin
# sda : sda
# membela : bela
# mendukung : dukung
# pelaku : laku
# kejahatan : jahat
# lgbtnya : lgbtnya
# ngomong : ngomong
# pidana : pidana
# deababiel : deababiel
# cinta : cinta
# inggris : inggris
# bangga : bangga
# brengos : brengos
# tua : tua
# sok : sok
# sokan : sok
# komentar : komentar
# bahaya : bahaya
# pejaten : pejaten
# ketua : ketua
# mematikan : mati
# mic : mic
# rapat : rapat
# pembahasan : bahas
# lgbtbukan : lgbtbukan
# sial : sial
# suami : suami
# cpa : cpa
# lom : lom
# perangkat : perangkat
# hukum : hukum
# menjerat : jerat
# dirs : dirs
# pelintirannya : pelintir
# dicuitkan : cuit
# judul : judul
# beritanya : berita
# ce : ce
# yess : yess
# ane : ane
# out : out
# harga : harga
# mati : mati
# menentang : tentang
# dikasih : kasih
# ruang : ruang
# organisasi : organisasi
# kesehatan : sehat
# who : who
# peringatan : ingat
# penyakit : sakit
# cacar : cacar
# monyet : monyet
# monkeypox : monkeypox
# lonjakan : lonjak
# sehipokrit : hipokrit
# bersikap : sikap
# poligami : poligami
# ditentang : tentang
# cadar : cadar
# dilarang : larang
# bersifat : sifat
# silalahi : silalahi
# giliran : gilir
# lantang : lantang
# bersuara : suara
# menghormati : hormat
# tanah : tanah
# rakyat : rakyat
# dirampas : rampas
# upah : upah
# murah : murah
# pro : pro
# buang : buang
# jurang : jurang
# terdalam : dalam
# uu : uu
# perzinaan : zina
# berlaku : laku
# berzina : zina
# persatuan : satu
# tukang : tukang
# zina : zina
# kekonyolan : konyol
# loe : loe
# pake : pake
# argumen : argumen
# terbalik : balik
# orang : orang
# sehat : sehat
# menularkan : tular
# takdir : takdir
# sam : sam
# brodie : brodie
# terlambat : lambat
# usia : usia
# samuel : samuel
# david : david
# alexander : alexander
# bima : bima
# kader : kader
# muhammadiyah : muhammadiyah
# sindir : sindir
# ketum : tum
# pbnu : pbnu
# urusan : urus
# diurus : urus
# viralin : viralin
# isu : isu
# radikal : radikal
# radikul : radikul
# periode : periode
# kriminalisasi : kriminalisasi
# ulama : ulama
# adu : adu
# domba : domba
# anis : anis
# bong : bong
# spesies : spesies
# kumpul : kumpul
# kuningan : kuningan
# iniada : iniada
# aming : aming
# tokoh : tokoh
# bicara : bicara
# silahkan : silah
# mencatat : catat
# partai : partai
# politisi : politis
# sodom : sodom
# melawan : lawan
# norma : norma
# tenggelamken : tenggelamken
# obat : obat
# penggugur : gugur
# kandungan : kandung
# original : original
# ready : ready
# stok : stok
# membantu : bantu
# tuntas : tuntas
# respon : respon
# cepat : cepat
# panggung : panggung
# sat : sat
# set : set
# melaporkan : lapor
# rasisnya : ras
# ruhut : ruhut
# eh : eh
# taunya : tau
# pembela : bela
# larang : larang
# tagar : tagar
# dibiarkan : biar
# tumbuh : tumbuh
# masyarakat : masyarakat
# mari : mari
# pemerintah : perintah
# menetapkan : tetap
# indo : indo
# kedubes : dubes
# lbh : lbh
# pelita : pelita
# umat : umat
# lancang : lancang
# tolak : tolak
# keras : keras
# world : world
# cup : cup
# disusupi : susup
# pesanan : pesan
# keren : keren
# pembelanya : bela
# as : as
# hormati : hormat
# dosa : dosa
# allah : allah
# cerdas : cerdas
# mnwmnw : mnwmnw
# konon : konon
# uas : uas
# desember : desember
# ahong : ahong
# ranah : ranah
# privat : privat
# diurusin : diurusin
# urusin : urusin
# mempromosikan : promosi
# sampe : sampe
# betelor : betelor
# statement : statement
# disambungin : disambungin
# malam : malam
# mengadakan : ada
# pentas : pentas
# lengger : lengger
# kesenian : seni
# tradisional : tradisional
# dibawakan : bawa
# penari : tari
# perempuan : perempuan
# skrg : skrg
# matiin : matiin
# besok : besok
# anak : anak
# dipaksa : paksa
# mengikuti : ikut
# pendidikan : didik
# seks : seks
# versi : versi
# menolak : tolak
# jano : jano
# kui : kui
# singkatane : singkatane
# opo : opo
# to : to
# min : min
# perilaku : perilaku
# penyimpangan : simpang
# seksual : seksual
# propagandanya : propaganda
# kian : kian
# meresahkan : resah
# mengancam : ancam
# generasi : generasi
# muda : muda
# iya : iya
# bahas : bahas
# kemana : mana
# akal : akal
# sehatnya : sehat
# cek : cek
# fakta : fakta
# gus : gus
# diinterpretasikan : interpretasi
# ditafsirkan : tafsir
# setuju : tuju
# sexual : sexual
# consent : consent
# kekosongan : kosong
# aturan : atur
# hatihati : hatihati
# azab : azab
# mengerikan : keri
# sidang : sidang
# paripurna : paripurna
# dpr : dpr
# pagi : pagi
# interupsi : interupsi
# terkait : kait
# berharap : harap
# sanksi : sanksi
# hizo : hizo
# herufi : herufi
# za : za
# watanzania : watanzania
# karibu : karibu
# wote : wote
# hawazijui : hawazijui
# hata : hata
# zinamaanisha : zinamaanisha
# nini : nini
# puan : puan
# matikan : mati
# fraksi : fraksi
# pks : pks
# tifatul : tifatul
# sembiring : sembiring
# sarkas : sarkas
# hemat : hemat
# listrik : listrik
# faktor : faktor
# ngerasain : ngerasain
# berbeda : beda
# ngeklaim : ngeklaim
# gender : gender
# dysphoria : dysphoria
# manapun : mana
# menghalalkan : halal
# kecuali : kecuali
# sakit : sakit
# jiwa : jiwa
# sridianava : sridianava
# haloo : haloo
# warga : warga
# nahdliyin : nahdliyin
# lurusjangan : lurusjangan
# cucu : cucu
# be : be
# konsep : konsep
# islam : islam
# ttg : ttg
# lgbtislam : lgbtislam
# dr : dr
# fitrah : fitrah
# pria : pria
# wanita : wanita
# shg : shg
# dilrg : dilrg
# mungkar : mungkar
# agr : agr
# lgbtindonesia : lgbtindonesia
# populasi : populasi
# terbesar : besar
# sewajarnya : wajar
# me : me
# silakan : sila
# dalih : dalih
# asasi : asasi
# anakmu : anak
# kena : kena
# nicho : nicho
# muncung : muncung
# pengalaman : alam
# pribadi : pribadi
# perlakuan : laku
# terkutuk : kutuk
# thd : thd
# makasar : makasar
# thn : thn
# pulang : pulang
# publik : publik
# majemuk : majemuk
# bertahun : tahun
# akrab : akrab
# tradisi : tradisi
# pakai : pakai
# istil : istil
# ofmagadh : ofmagadh
# phir : phir
# shuru : shuru
# inka : inka
# bawa : bawa
# roh : roh
# suci : suci
# allahrentetan : allahrentetan
# peristiwa : peristiwa
# nyata : nyata
# ditengah : tengah
# deddy : deddy
# mengunda : unda
# bandingin : bandingin
# gilang : gilang
# kntdd : kntdd
# mikir : mikir
# makan : makan
# id : id
# budayawan : budayawan
# wajib : wajib
# lawan : lawan
# dubes : dubes
# ngambekkan : ngambekkan
# kedaulatannya : daulat
# negaramu : negara
# bermingg : bermingg
# following : following
# berkurang : kurang
# beneran : beneran
# cari : cari
# dpt : dpt
# bamukmin : bamukmin
# gegabah : gegabah
# heineken : heineken
# sponsorship : sponsorship
# buk : buk
# maaf : maaf
# bang : bang
# muslim : muslim
# ber : ber
# namanya : nama
# lgbttapi : lgbttapi
# bis : bis
# majelis : majelis
# mui : mui
# bidang : bidang
# dakwah : dakwah
# ukhuwah : ukhuwah
# kh : kh
# muhammad : muhammad
# cholil : cholil
# nafis : naf
# dipidana : pidana
# guskami : guskami
# mohoncuma : mohoncuma
# satunya : satu
# harapan : harap
# bernaung : naung
# ngomongin : ngomongin
# babi : babi
# heboh : heboh
# lingk : lingk
# anggota : anggota
# dewan : dewan
# singgung : singgung
# langsung : langsung
# terserah : serah
# kesalahan : salah
# apapun : apa
# gada : gada
# halah : halah
# bokefer : bokefer
# pendukung : dukung
# kumurkumur : kumurkumur
# norak : norak
# son : son
# getol : getol
# aktivis : aktivis
# gerah : gerah
# kafir : kafir
# gemar : gemar
# menstigma : stigma
# makhluk : makhluk
# jamin : jamin
# perbuatan : buat
# angka : angka
# didu : didu
# om : om
# sendri : sendri
# akibat : akibat
# mu : mu
# terbuka : buka
# lesbian : lesbian
# gay : gay
# biseksual : biseksual
# transg : transg
# ustadz : ustadz
# abdul : abdul
# somad : somad
# pemberian : beri
# tuhan : tuhan
# kanjengraden : kanjengraden
# formula : formula
# sponsor : sponsor
# birlgbt : birlgbt
# daerah : daerah
# kadrun : kadrun
# padang : padang
# bogorpemerkosaan : bogorpemerkosaan
# massal : massal
# santrigabener : santrigabener
# pelukan : peluk
# lildove : lildove
# tolol : tolol
# bener : bener
# nyesel : nyesel
# gua : gua
# nungguin : nungguin
# bertaun : taun
# liat : liat
# plot : plot
# cacat : cacat
# ala : ala
# netflix : netflix
# suka : suka
# campaign : campaign
# lgbtsaya : lgbtsaya
# dere : dere
# semoga : moga
# keturunan : turun
# elu : elu
# berperilaku : perilaku
# lgbtaamiin : lgbtaamiin
# memenuhi : penuh
# tugas : tugas
# nulis : nulis
# negeri : negeri
# adat : adat
# jg : jg
# lu : lu
# betina : betina
# jantan : jantan
# enak : enak
# gw : gw
# panggil : panggil
# lihat : lihat
# wajah : wajah
# kayak : kayak
# bullhit : bullhit
# hilang : hilang
# kehormatan : hormat
# maksud : maksud
# mengharga : harga
# bersumpah : sumpah
# nama : nama
# musyrik : musyrik
# all : all
# shandie : shandie
# cucunya : cucu
# perokok : okok
# berhenti : henti
# debat : debat
# ngeyel : ngeyel
# divonis : vonis
# strokebegitupun : strokebegitupun
# hivims : hivims
# langsun : langsun
# walah : walah
# logika : logika
# ni : ni
# vs : vs
# alkohol : alkohol
# standar : standar
# apel : apel
# apelkalo : apelkalo
# udah : udah
# bs : bs
# lahsudah : lahsudah
# waktunyarakyat : waktunyarakyat
# melawanketidak : melawanketidak
# adilan : adil
# masak : masak
# kalah : kalah
# tekanan : tekan
# lsm : lsm
# fifa : fifa
# jadikan : jadi
# sbagai : sbagai
# negosiatorbiar : negosiatorbiar
# smpaikanurusan : smpaikanurusan
# web : web
# boskuh : boskuh
# bonus : bonus
# garansi : garansi
# potonganlink : potonganlink
# daftar : daftar
# nneve : nneve
# untung : untung
# muhamadiyah : muhamadiyah
# mnentang : mnentang
# pengesahan : kesah
# perwkilan : perwkilan
# nahdatul : nahdatul
# selamat : selamat
# sore : sore
# cherybol : cherybol
# lgbtkumpulan : lgbtkumpulan
# mencoba : coba
# memaksakan : paksa
# memaksa : paksa
# komisioner : komisioner
# trendingnya : trendingnya
# jelek : jelek
# bkn : bkn
# kriminal : kriminal
# seenak : enak
# udel : udel
# bawabawa : bawabawa
# penjara : penjara
# urusannya : urus
# hadeh : hadeh
# wakanda : wakanda
# wajar : wajar
# bernapas : napas
# doang : doang
# masuk : masuk
# aowwkwowk : aowwkwowk
# kocak : kocak
# gemingg : gemingg
# istri : istri
# nabi : nabi
# luth : luth
# lgbtkami : lgbtkami
# ngakak : ngakak
# trending : trending
# kirain : kirain
# pidanain : pidanain
# ngabrutttt : ngabrutttt
# stop : stop
# judging : judging
# people : people
# pemikiran : pikir
# kolot : kolot
# it : it
# hargai : harga
# thats : thats
# membawa : bawa
# aturannya : atur
# memenjarakan : penjara
# for : for
# no : no
# reason : reason
# just : just
# becaus : becaus
# seumur : umur
# hidupnya : hidup
# bertapa : tapa
# menyalurkan : salur
# hasrat : hasrat
# seksualnya : seksual
# bbrp : bbrp
# boca : boca
# best : best
# seller : seller
# inone : inone
# wireless : wireless
# bluetooth : bluetooth
# headset : headset
# with : with
# kst : kst
# music : music
# year : year
# official : official
# warrantyrp : warrantyrp
# diskon : diskon
# niih : niih
# bani : bani
# tusbol : tusbol
# pendukungnyabacalah : pendukungnyabacalah
# tantangan : tantang
# dimana : mana
# berubah : ubah
# belain : bain
# lesbi : lesbi
# girang : girang
# panggilan : panggil
# gas : gas
# narkoba : narkoba
# kecanduan : candu
# rusak : rusak
# buru : buru
# micjangan : micjangan
# aaasssuu : aaasssuu
# dahlah : dah
# jepang : jepang
# meibbfs : meibbfs
# bb : bb
# shot : shot
# heryanto : heryanto
# tulisan : tulis
# ditulis : tulis
# media : media
# memuatnya : muat
# nkri : nkri
# dikuasai : asai
# pengkhianat : khianat
# pelanggar : langgar
# uud : uud
# berusaha : usaha
# menyusupkan : susup
# liberal : liberal
# lgbtislamophobia : lgbtislamophobia
# macau : macau
# jus : jus
# berkembang : kembang
# cokro : cokro
# tvkok : tvkok
# dilaporkan : lapor
# polda : polda
# metro : metro
# lurah : lurah
# istanakatanya : istanakatanya
# istana : istana
# dil : dil
# bahagia : bahagia
# hiv : hiv
# aids : aids
# sipilis : sipil
# revisi : revisi
# kuhp : kuhp
# menjijikan : jijik
# korban : korban
# halu : halu
# membongkar : bongkar
# istanapantas : istanapantas
# pem : pem
# pov : pov
# lgi : lgi
# org : org
# lol : lol
# damn : damn
# nsfw : nsfw
# ngabrut : ngabrut
# dlm : dlm
# ceramahnya : ceramah
# menyebut : sebut
# hina : hina
# hewan : hewan
# ayam : ayam
# jago : jago
# mencari : cari
# dasar : dasar
# pelarangan : larang
# nasi : nasi
# mawut : mawut
# tersesat : sesat
# ideologi : ideologi
# penetapan : tetap
# rkuhp : rkuhp
# mengatur : atur
# https : https
# dibenarkan : benar
# keberadaan : ada
# dasarnya : dasar
# sud : sud
# calon : calon
# plecidenkenapa : plecidenkenapa
# kelakuan : laku
# bginiapa : bginiapa
# pendukun : dukun
# marah : marah
# dikibarkan : kibar
# ambil : ambil
# pusing : pusing
# dinaikkan : naik
# jaga : jaga
# diwakanda : diwakanda
# ormas : ormas
# ngaku : ngaku
# tp : tp
# swmua : swmua
# dihinaka : dihinaka
# kemarin : kemarin
# sd : sd
# sh : sh
# hidupkah : hidup
# coba : coba
# meme : meme
# menyegarkan : segar
# otak : otak
# membandi : membandi
# inotav : inotav
# benertapi : benertapi
# ceramah : ceramah
# bel : bel
# bungo : bungo
# menyandingkan : sanding
# atheis : atheis
# aneh : aneh
# hehehe : hehehe
# mencaci : caci
# maki : maki
# berdiskusi : diskus
# sudut : sudut
# pandang : pandang
# disk : disk
# ak : ak
# cabang : cabang
# lgbtia : lgbtia
# pihakpihak : pihakpihak
# kelompok : kelompok
# kebebasan : bebas
# segi : segi
# hukumnya : hukum
# bot : bot
# menular : tular
# respons : respons
# mahfud : mahfud
# komisi : komisi
# iii : iii
# pastikan : pasti
# lgbtzina : lgbtzina
# draf : draf
# rkuhpyes : rkuhpyes
# apani : apani
# lahh : lahh
# sila : sila
# pelintiran : pelintir
# sikap : sikap
# and : and
# seakan : akan
# memancing : pancing
# berbuat : buat
# demik : demik
# ngaruh : ngaruh
# ntar : ntar
# dibumi : bumi
# punah : punah
# bagus : bagus
# oran : oran
# transgender : transgender
# identik : identik
# pelangi : pelangi
# menyi : nyi
# membahas : bahas
# perspektif : perspektif
# nasional : nasional
# gerakan : gera
# proyek : proyek
# dikelola : kelola
# badan : badan
# internasional : internasional
# covid : covid
# dituduh : tuduh
# dalang : dalang
# beliau : beliau
# skrang : skrang
# suruh : suruh
# wh : wh
# ooo : ooo
# itulgbt : itulgbt
# peradaban : adab
# klen : klen
# main : main
# yih : yih
# rscm : rscm
# rs : rs
# dharmais : dharmais
# gimana : gimana
# tim : tim
# sempetin : sempetin
# nunjukin : nunjukin
# dukungan : dukung
# ngotot : ngotot
# pikir : pikir
# ortu : ortu
# sin : sin
# is : is
# sintidak : sintidak
# lagu : lagu
# an : an
# lgbtallah : lgbtallah
# swt : swt
# melaknat : laknat
# lgbtini : lgbtini
# mengerti : erti
# ajaran : ajar
# marm : marm
# mengutuk : kutuk
# agus : agus
# nyuruh : nyuruh
# pala : pala
# lo : lo
# bauk : bauk
# jarang : jarang
# iklan : iklan
# rokok : rokok
# dri : dri
# sosmed : sosmed
# esse : esse
# beli : beli
# mbak : mbak
# menyinggung : singgung
# sua : sua
# capable : capable
# memimpin : pimpin
# berkuasa : kuasa
# mengurus : urus
# kenapasihhh : kenapasihhh
# krisis : krisis
# iklim : iklim
# kekerasan : keras
# domestik : domestik
# ketimpangan : timpang
# kelas : kelas
# gede : gede
# fokus : fokus
# apaapa : apaapa
# tingkat : tingkat
# intelegensi : intelegensi
# rendah : rendah
# dibandingkan : banding
# kawin : kawin
# sejenis : jenis
# bisexsual : bisexsual
# transgenderpenyakit : transgenderpenyakit
# terlaknatrasulullah : terlaknatrasulullah
# shalallahu : shalallahu
# alaihi : alaihi
# wasallam : wasallam
# bers : bers
# antilgbt : antilgbt
# ngundang : ngundang
# pasangan : pasang
# kontroversial : kontroversial
# pindah : pindah
# kacang : kacang
# sea : sea
# salah : salah
# malaysia : malaysia
# ibhrs : ibhrs
# retweet : retweet
# like : like
# nindak : nindak
# ngehukum : ngehukum
# emang : emang
# nasib : nasib
# tutup : tutup
# pintu : pintu
# kantor : kantor
# membiarkan : biar
# highlight : highlight
# story : story
# instagram : instagram
# urai : urai
# perkara : perkara
# syiah : syiah
# lainlain : lainlain
# cebong : cebong
# homo : homo
# gagal : gagal
# operasi : operasi
# namakilurahsudah : namakilurahsudah
# sebar : sebar
# grup : grup
# wa : wa
# pesan : pesan
# seha : seha
# bro : bro
# dizaman : zaman
# kenabiian : kenabiian
# melecehkan : leceh
# negar : negar
# memperkecil : kecil
# potensi : potensi
# penularan : tular
# menaikkan : naik
# mental : mental
# disembuhkan : sembuh
# republika : republika
# mobile : mobile
# bcd : bcd
# chattan : chattan
# dululgbt : dululgbt
# btajg : btajg
# astagfirullah : astagfirullah
# gitum : gitum
# ajgajg : ajgajg
# gelar : gelar
# acara : acara
# makassar : makassar
# sulsel : sulsel
# hidayatullah : hidayatullah
# sleman : sleman
# blazer : blazer
# ngantor : ngantor
# rating : rating
# thread : thread
# anyingg : anyingg
# ticket : ticket
# pesawat : pesawat
# afganistan : afganistan
# sewain : sewain
# hotel : hotel
# akomodasi : akomodasi
# us : us
# james : james
# martin : martin
# sj : sj
# perjumpaan : jumpa
# gereja : gereja
# via : via
# net : net
# boti : bot
# hbgn : hbgn
# emg : emg
# arti : arti
# bonceng : bonceng
# ngerti : ngerti
# sieeee : sieeee
# curhat : curhat
# amin : amin
# miknya : mik
# menyuarakan : suara
# lgbtyang : lgbtyang
# yunianto : yunianto
# percayalah : percaya
# bahagiakebahagiaan : bahagiakebahagiaan
# semu : semu
# dikejarberujung : dikejarberujung
# derita : derita
# nihabang : nihabang
# lgbtsya : lgbtsya
# tanyaapa : tanyaapa
# abang : abang
# jdi : jdi
# lgbtsebab : lgbtsebab
# bingung : bingung
# banget : banget
# pasca : pasca
# podcast : podcast
# corbuzier : corbuzier
# rezim : rezim
# jokowi : jokowi
# opm : opm
# jlas : jlas
# troris : troris
# kga : kga
# total : total
# lawannyamalah : lawannyamalah
# disbut : disbut
# sodaratag : sodaratag
# semarang : semarang
# ganjar : ganjar
# pranowo : pranowo
# pekalongan : kalong
# ekokuntadhi : ekokuntadhi
# kaya : kaya
# penggiat : giat
# medsos : medsos
# penebar : tebar
# teror : teror
# dianggap : anggap
# teroris : teroris
# isi : isi
# penafsiranya : penafsiranya
# argunemtasi : argunemtasi
# membenarkan : benar
# argumentasi : argumentasi
# ngaw : ngaw
# anus : anus
# qatarlgbt : qatarlgbt
# laknat : laknat
# kasih : kasih
# inilgbt : inilgbt
# terhina : hina
# bgn : bgn
# lgbtapaanda : lgbtapaanda
# senang : senang
# klau : klau
# klg : klg
# penikmat : nikmat
# lobang : lobang
# taiapakah : taiapakah
# penikma : penikma
# sayang : sayang
# skrng : skrng
# open : open
# vcs : vcs
# curahan : curah
# hati : hati
# inong : inong
# menghadapi : hadap
# pasien : pasien
# menyedihkan : sedih
# kor : kor
# siaga : siaga
# lindungi : lindung
# keluarga : keluarga
# fan : fan
# laten : laten
# komunisme : komunisme
# sailing : sailing
# bahu : bahu
# membahu : bahu
# hancurkan : hancur
# bertanggung : tanggung
# koruptor : koruptor
# triliunan : triliun
# bebas : bebas
# utang : utang
# numpuk : numpuk
# penciptaan : cipta
# ruh : ruh
# menghembuskan : hembus
# asma : asma
# rosulnya : rosulnya
# dah : dah
# brojol : brojol
# bongdrun : bongdrun
# selebtwit : selebtwit
# nyaterutama : nyaterutama
# bodoh : bodoh
# gratisan : gratis
# cebongkalian : cebongkalian
# benci : benci
# dll : dll
# tern : tern
# perbincangan : bincang
# hangat : hangat
# dibuktikan : bukti
# berturutturut : berturutturut
# kebingungan : bingung
# bugis : bugis
# sperti : sperti
# dipikiranmmg : dipikiranmmg
# casing : casing
# laintp : laintp
# kehilangan : hilang
# dibela : bela
# cemooh : cemooh
# dilaknat : laknat
# imbasnya : imbas
# nga : nga
# becandaan : becandaan
# berjuang : juang
# alasan : alas
# ham : ham
# melindunginya : lindung
# lupa : lupa
# merombak : rombak
# penelitian : teliti
# homophobia : homophobia
# toleran : toleran
# ama : ama
# anti : anti
# samasama : samasama
# dikas : kas
# menjangkit : jangkit
# level : level
# menengah : tengah
# atascoba : atascoba
# beranikah : berani
# dprri : dprri
# berfoto : foto
# dibawahnya : bawah
# darius : darius
# sinathrya : sinathrya
# blakblakan : blakblakan
# tudingan : tuding
# yos : yos
# intelijenberpikirnya : intelijenberpikirnya
# prediksi : prediksi
# terburuk : buruk
# datangjadi : datangjadi
# waspada : waspada
# keahlian : ahli
# mik : mik
# melewati : lewat
# menit : menit
# mas : mas
# ali : ali
# bhineka : bhineka
# tunggal : tunggal
# ika : ika
# beda : beda
# satulgbt : satulgbt
# perbedaan : beda
# dibikin : bikin
# kecamatan : camat
# ngeri : ngeri
# kuat : kuat
# melindungi : lindung
# srg : srg
# jambret : jambret
# dapet : dapet
# hukuman : hukum
# membenarkandi : membenarkandi
# denger : denger
# pas : pas
# kah : kah
# cocok : cocok
# menerapkan : terap
# syariat : syariat
# brunei : brunei
# darussalam : darussalam
# inisiatif : inisiatif
# menghukum : hukum
# gerogoti : gerogot
# yahudi : yahudi
# menyusup : susup
# buni : buni
# yani : yani
# ingatkan : ingat
# haram : haram
# komunis : komunis
# lgbtagama : lgbtagama
# fantesa : fantesa
# pi : pi
# ad : ad
# superior : superior
# ciri : ciri
# sekian : sekian
# arogan : arogan
# didukung : dukung
# pengajian : aji
# dibubarkan : bubar
# now : now
# ditemukan : temu
# mendengar : dengar
# tent : tent
# lbgt : lbgt
# prilaku : prilaku
# disem : disem
# elit : elit
# bukti : bukti
# tsb : tsb
# suram : suram
# membusukpantas : membusukpantas
# ku : ku
# tweetmu : tweetmu
# botak : botak
# smart : smart
# pipel : pipel
# dikambinghitamkan : dikambinghitamkan
# merangkai : rangkai
# dukadulu : dukadulu
# takut : takut
# menjaga : jaga
# prempuan : prempuan
# lakitulisan : lakitulisan
# ani : ani
# mn : mn
# kl : kl
# bnr : bnr
# tuduh : tuduh
# abal : abal
# brkwalitas : brkwalitas
# gtu : gtu
# kliatan : kliatan
# pinter : pinter
# grant : grant
# vonis : vonis
# adl : adl
# psikologi : psikologi
# mem : mem
# menko : menko
# polhukam : polhukam
# md : md
# kat : kat
# bathil : bathil
# pahit : pahit
# rasakandaripa : rasakandaripa
# susah : susah
# kenyataannya : nyata
# keadilan : adil
# cemilan : cemilan
# {'dukung': 'dukung', 'pidanakan': 'pidana', 'lgbt': 'lgbt', 'hidayat': 'hidayat', 'nurwahid': 'nurwahid', 'bertentangan': 'tentang', 'pancasila': 'pancasila', 'rekomendasi': 'rekomendasi', 'kemeja': 'kemeja', 'retro': 'retro', 'sista': 'sista', 'nggak': 'nggak', 'kek': 'kek', 'firaun': 'firaun', 'tag': 'tag', 'libur': 'libur', 'siang': 'siang', 'ozil': 'ozil', 'kacaunya': 'kacau', 'portal': 'portal', 'online': 'online', 'belajar': 'ajar', 'menulis': 'tulis', 'berita': 'berita', 'cuitan': 'cuit', 'nadir': 'nadir', 'dibenturkan': 'bentur', 'pernyataan': 'nyata', 'hrs': 'hrs', 'porn': 'porn', 'cebol': 'cebol', 'berani': 'berani', 'nongol': 'nongol', 'ditampol': 'ditampol', 'khusus': 'khusus', 'oposisi': 'oposisi', 'salfol': 'salfol', 'toko': 'toko', 'nu': 'nu', 'jualan': 'jual', 'kaum': 'kaum', 'predator': 'predator', 'normal': 'normal', 'mrk': 'mrk', 'berburu': 'buru', 'sebyk': 'sebyk', 'mgkn': 'mgkn', 'manusia': 'manusia', 'bareng': 'bareng', 'nyembah': 'nyembah', 'iblis': 'iblis', 'msk': 'msk', 'neraka': 'neraka', 'mengundang': 'undang', 'bencana': 'bencana', 'alam': 'alam', 'peduli': 'peduli', 'lingkungan': 'lingkung', 'gue': 'gue', 'maksanya': 'maksanya', 'btw': 'btw', 'hidup': 'hidup', 'berdampingan': 'damping', 'ente': 'ente', 'sumut': 'sumut', 'perangi': 'rang', 'tu': 'tu', 'disitu': 'situ', 'cmn': 'cmn', 'koar': 'koar', 'kerja': 'kerja', 'nyepil': 'nyepil', 'gitu': 'gitu', 'dibilang': 'bilang', 'buzzerp': 'buzzerp', 'mulut': 'mulut', 'sampah': 'sampah', 'bisanya': 'bisa', 'mengkritik': 'kritik', 'kinerja': 'kerja', 'berseberangan': 'berangan', 'nonton': 'nonton', 'menyimpang': 'simpang', 'alias': 'alias', 'off': 'off', 'ukhty': 'ukhty', 'ri': 'ri', 'dimatikan': 'mati', 'cair': 'cair', 'cuan': 'cuan', 'komunitas': 'komunitas', 'sekedar': 'dar', 'nanya': 'nanya', 'heran': 'heran', 'indonesia': 'indonesia', 'kebanyakan': 'banyak', 'munafik': 'munafik', 'memperjuangkan': 'juang', 'hak': 'hak', 'fyi': 'fyi', 'tindak': 'tindak', 'pidananya': 'pidana', 'disaat': 'saat', 'mengucilkan': 'kucil', 'menjauhkan': 'jauh', 'keluarganya': 'keluarga', 'teriak': 'teriak', 'bendera': 'bendera', 'tauhid': 'tauhid', 'antum': 'antum', 'bakar': 'bakar', 'kibarkan': 'kibar', 'kebenaran': 'benar', 'salahkan': 'salah', 'kebatilan': 'batil', 'bela': 'bela', 'qatar': 'qatar', 'haramkan': 'haram', 'piala': 'piala', 'dunia': 'dunia', 'menukar': 'tukar', 'agama': 'agama', 'turnamen': 'turnamen', 'qi': 'qi', 'surga': 'surga', 'buron': 'buron', 'korupsi': 'korupsi', 'singapore': 'singapore', 'lgbthanya': 'lgbthanya', 'negara': 'negara', 'broker': 'broker', 'miskin': 'miskin', 'sda': 'sda', 'membela': 'bela', 'mendukung': 'dukung', 'pelaku': 'laku', 'kejahatan': 'jahat', 'lgbtnya': 'lgbtnya', 'ngomong': 'ngomong', 'pidana': 'pidana', 'deababiel': 'deababiel', 'cinta': 'cinta', 'inggris': 'inggris', 'bangga': 'bangga', 'brengos': 'brengos', 'tua': 'tua', 'sok': 'sok', 'sokan': 'sok', 'komentar': 'komentar', 'bahaya': 'bahaya', 'pejaten': 'pejaten', 'ketua': 'ketua', 'mematikan': 'mati', 'mic': 'mic', 'rapat': 'rapat', 'pembahasan': 'bahas', 'lgbtbukan': 'lgbtbukan', 'sial': 'sial', 'suami': 'suami', 'cpa': 'cpa', 'lom': 'lom', 'perangkat': 'perangkat', 'hukum': 'hukum', 'menjerat': 'jerat', 'dirs': 'dirs', 'pelintirannya': 'pelintir', 'dicuitkan': 'cuit', 'judul': 'judul', 'beritanya': 'berita', 'ce': 'ce', 'yess': 'yess', 'ane': 'ane', 'out': 'out', 'harga': 'harga', 'mati': 'mati', 'menentang': 'tentang', 'dikasih': 'kasih', 'ruang': 'ruang', 'organisasi': 'organisasi', 'kesehatan': 'sehat', 'who': 'who', 'peringatan': 'ingat', 'penyakit': 'sakit', 'cacar': 'cacar', 'monyet': 'monyet', 'monkeypox': 'monkeypox', 'lonjakan': 'lonjak', 'sehipokrit': 'hipokrit', 'bersikap': 'sikap', 'poligami': 'poligami', 'ditentang': 'tentang', 'cadar': 'cadar', 'dilarang': 'larang', 'bersifat': 'sifat', 'silalahi': 'silalahi', 'giliran': 'gilir', 'lantang': 'lantang', 'bersuara': 'suara', 'menghormati': 'hormat', 'tanah': 'tanah', 'rakyat': 'rakyat', 'dirampas': 'rampas' ...
# ------------------------
# Pandas Apply:   0%|          | 0/269 [00:00<?, ?it/s]
# Hasil Stemming :
#                                                tweet  \
# 0  rt dukung pidanakan lgbt hidayat nurwahid lgbt...
# 1  rekomendasi kemeja retro sista yang jelas ngga...
# 2  rt inilah kacaunya portal online yang tak bela...
# 3  porn lgbt dan cebol jangan berani nongol kalo ...
# 4                             rt toko nu jualan lgbt
#
#                                         tweet_tokens  \
# 0  [rt, dukung, pidanakan, lgbt, hidayat, nurwahi...
# 1  [rekomendasi, kemeja, retro, sista, yang, jela...
# 2  [rt, inilah, kacaunya, portal, online, yang, t...
# 3  [porn, lgbt, dan, cebol, jangan, berani, nongo...
# 4                       [rt, toko, nu, jualan, lgbt]
#
#                                     tweet_tokens_WSW  \
# 0  [dukung, pidanakan, lgbt, hidayat, nurwahid, l...
# 1  [rekomendasi, kemeja, retro, sista, nggak, kek...
# 2  [kacaunya, portal, online, belajar, menulis, b...
# 3  [porn, lgbt, cebol, berani, nongol, ditampol, ...
# 4                           [toko, nu, jualan, lgbt]
#
#                                 tweet_tokens_stemmed
# 0  [dukung, pidana, lgbt, hidayat, nurwahid, lgbt...
# 1  [rekomendasi, kemeja, retro, sista, nggak, kek...
# 2  [kacau, portal, online, ajar, tulis, berita, c...
# 3  [porn, lgbt, cebol, berani, nongol, ditampol, ...
# 4                             [toko, nu, jual, lgbt]

# %%
TWEET_DATA.to_csv("LGBT_clean.csv")

# %%
TWEET_DATA = pd.read_csv("LGBT_clean.csv")
TWEET_DATA.columns = ['tweet']

# menampilkan data bagian head
TWEET_DATA.head()
# Out:
#                                                tweet
# 0  ['dukung', 'pidana', 'lgbt', 'hidayat', 'nurwa...
# 1  ['rekomendasi', 'kemeja', 'retro', 'sista', 't...
# 2  ['kacau', 'portal', 'online', 'ajar', 'tulis',...
# 3  ['porn', 'lgbt', 'cebol', 'berani', 'muncul', ...
# 4                           ['toko', 'jual', 'lgbt']
